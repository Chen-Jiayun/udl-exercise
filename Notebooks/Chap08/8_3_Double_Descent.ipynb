# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.300231, train error 88.60,  test loss 2.299820, test error 89.22
# Epoch   100, train loss 1.895220, train error 70.93,  test loss 1.738117, test error 69.60
# Epoch   200, train loss 1.875508, train error 70.10,  test loss 1.703529, test error 68.40
# Epoch   300, train loss 1.857822, train error 70.22,  test loss 1.682079, test error 68.25
# Epoch   400, train loss 1.847458, train error 69.97,  test loss 1.668805, test error 66.35
# Epoch   500, train loss 1.847517, train error 69.55,  test loss 1.673671, test error 66.78
# Epoch   600, train loss 1.844709, train error 70.43,  test loss 1.675346, test error 67.10
# Epoch   700, train loss 1.843506, train error 69.82,  test loss 1.672534, test error 66.72
# Epoch   800, train loss 1.846808, train error 70.18,  test loss 1.673534, test error 66.62
# Epoch   900, train loss 1.846971, train error 70.53,  test loss 1.682344, test error 67.95
# Training model with   4 hidden variables
# Epoch     0, train loss 2.251455, train error 83.15,  test loss 2.236701, test error 81.75
# Epoch   100, train loss 1.752771, train error 62.92,  test loss 1.563437, test error 59.72
# Epoch   200, train loss 1.714223, train error 61.95,  test loss 1.543317, test error 59.90
# Epoch   300, train loss 1.697754, train error 60.90,  test loss 1.517101, test error 58.60
# Epoch   400, train loss 1.712416, train error 61.95,  test loss 1.521088, test error 59.50
# Epoch   500, train loss 1.693935, train error 61.00,  test loss 1.497595, test error 58.45
# Epoch   600, train loss 1.688694, train error 60.95,  test loss 1.497056, test error 58.20
# Epoch   700, train loss 1.696411, train error 61.58,  test loss 1.506273, test error 57.67
# Epoch   800, train loss 1.696721, train error 60.85,  test loss 1.503559, test error 57.00
# Epoch   900, train loss 1.687928, train error 59.95,  test loss 1.497147, test error 57.55
# Training model with   6 hidden variables
# Epoch     0, train loss 2.289565, train error 86.53,  test loss 2.289912, test error 86.40
# Epoch   100, train loss 1.711871, train error 61.25,  test loss 1.563070, test error 59.47
# Epoch   200, train loss 1.637271, train error 56.92,  test loss 1.463193, test error 54.38
# Epoch   300, train loss 1.605558, train error 55.45,  test loss 1.450084, test error 53.65
# Epoch   400, train loss 1.600973, train error 55.83,  test loss 1.454324, test error 53.62
# Epoch   500, train loss 1.601914, train error 54.90,  test loss 1.463526, test error 53.15
# Epoch   600, train loss 1.589676, train error 55.05,  test loss 1.449695, test error 53.22
# Epoch   700, train loss 1.583998, train error 54.72,  test loss 1.442401, test error 53.25
# Epoch   800, train loss 1.580602, train error 54.55,  test loss 1.453501, test error 53.10
# Epoch   900, train loss 1.577170, train error 54.42,  test loss 1.443168, test error 53.92
# Training model with   8 hidden variables
# Epoch     0, train loss 2.270906, train error 87.32,  test loss 2.257298, test error 86.32
# Epoch   100, train loss 1.592227, train error 56.08,  test loss 1.426647, test error 55.85
# Epoch   200, train loss 1.543947, train error 53.95,  test loss 1.401911, test error 53.90
# Epoch   300, train loss 1.521869, train error 53.00,  test loss 1.399824, test error 53.15
# Epoch   400, train loss 1.517699, train error 52.62,  test loss 1.400511, test error 53.45
# Epoch   500, train loss 1.511368, train error 52.22,  test loss 1.396911, test error 53.40
# Epoch   600, train loss 1.512338, train error 52.17,  test loss 1.401912, test error 53.67
# Epoch   700, train loss 1.511119, train error 52.15,  test loss 1.396028, test error 53.22
# Epoch   800, train loss 1.497101, train error 51.17,  test loss 1.384614, test error 51.97
# Epoch   900, train loss 1.514148, train error 52.12,  test loss 1.414818, test error 53.45
# Training model with  10 hidden variables
# Epoch     0, train loss 2.233080, train error 82.22,  test loss 2.208486, test error 80.38
# Epoch   100, train loss 1.564784, train error 55.47,  test loss 1.411908, test error 53.15
# Epoch   200, train loss 1.504949, train error 53.15,  test loss 1.355451, test error 51.58
# Epoch   300, train loss 1.483894, train error 52.22,  test loss 1.356889, test error 51.22
# Epoch   400, train loss 1.480497, train error 51.80,  test loss 1.376742, test error 51.50
# Epoch   500, train loss 1.465494, train error 51.42,  test loss 1.383295, test error 51.88
# Epoch   600, train loss 1.464847, train error 50.88,  test loss 1.379591, test error 51.15
# Epoch   700, train loss 1.455153, train error 51.15,  test loss 1.394807, test error 51.60
# Epoch   800, train loss 1.454035, train error 51.42,  test loss 1.405005, test error 52.40
# Epoch   900, train loss 1.452999, train error 50.50,  test loss 1.403960, test error 52.42
# Training model with  14 hidden variables
# Epoch     0, train loss 2.178481, train error 80.65,  test loss 2.141047, test error 79.50
# Epoch   100, train loss 1.436543, train error 48.65,  test loss 1.324653, test error 50.42
# Epoch   200, train loss 1.343200, train error 44.90,  test loss 1.293738, test error 49.03
# Epoch   300, train loss 1.310559, train error 43.92,  test loss 1.291632, test error 48.55
# Epoch   400, train loss 1.290290, train error 43.50,  test loss 1.322430, test error 48.97
# Epoch   500, train loss 1.281238, train error 43.35,  test loss 1.345237, test error 49.75
# Epoch   600, train loss 1.267320, train error 42.67,  test loss 1.359685, test error 49.90
# Epoch   700, train loss 1.267560, train error 42.83,  test loss 1.371894, test error 49.88
# Epoch   800, train loss 1.261709, train error 42.80,  test loss 1.382517, test error 49.28
# Epoch   900, train loss 1.262897, train error 43.28,  test loss 1.398936, test error 50.15
# Training model with  18 hidden variables
# Epoch     0, train loss 2.229938, train error 81.85,  test loss 2.213826, test error 81.40
# Epoch   100, train loss 1.313284, train error 43.83,  test loss 1.270213, test error 47.40
# Epoch   200, train loss 1.248996, train error 42.28,  test loss 1.306697, test error 48.67
# Epoch   300, train loss 1.220509, train error 41.17,  test loss 1.340038, test error 48.88
# Epoch   400, train loss 1.197614, train error 40.33,  test loss 1.383978, test error 49.58
# Epoch   500, train loss 1.181569, train error 39.95,  test loss 1.412015, test error 50.30
# Epoch   600, train loss 1.173180, train error 39.67,  test loss 1.439610, test error 50.72
# Epoch   700, train loss 1.159217, train error 40.05,  test loss 1.455932, test error 50.65
# Epoch   800, train loss 1.154187, train error 40.08,  test loss 1.475003, test error 51.20
# Epoch   900, train loss 1.140829, train error 39.15,  test loss 1.474303, test error 50.60
# Training model with  22 hidden variables
# Epoch     0, train loss 2.160816, train error 78.85,  test loss 2.149231, test error 79.68
# Epoch   100, train loss 1.268169, train error 42.03,  test loss 1.347943, test error 49.62
# Epoch   200, train loss 1.142718, train error 38.53,  test loss 1.425567, test error 50.80
# Epoch   300, train loss 1.100034, train error 37.53,  test loss 1.482625, test error 51.53
# Epoch   400, train loss 1.059978, train error 36.22,  test loss 1.540402, test error 51.72
# Epoch   500, train loss 1.033073, train error 34.78,  test loss 1.592113, test error 51.12
# Epoch   600, train loss 1.030380, train error 34.68,  test loss 1.637332, test error 52.72
# Epoch   700, train loss 1.026373, train error 34.82,  test loss 1.688051, test error 53.08
# Epoch   800, train loss 0.997482, train error 33.85,  test loss 1.735469, test error 53.75
# Epoch   900, train loss 1.009503, train error 34.93,  test loss 1.771007, test error 54.03
# Training model with  26 hidden variables
# Epoch     0, train loss 2.173199, train error 80.18,  test loss 2.147291, test error 79.38
# Epoch   100, train loss 1.236391, train error 41.67,  test loss 1.447972, test error 54.20
# Epoch   200, train loss 1.092971, train error 36.67,  test loss 1.553471, test error 53.97
# Epoch   300, train loss 1.001707, train error 33.32,  test loss 1.654574, test error 53.90
# Epoch   400, train loss 0.954262, train error 32.18,  test loss 1.780297, test error 55.25
# Epoch   500, train loss 0.915406, train error 31.07,  test loss 1.926673, test error 55.35
# Epoch   600, train loss 0.891513, train error 29.70,  test loss 1.982788, test error 55.35
# Epoch   700, train loss 0.877584, train error 29.62,  test loss 2.075699, test error 55.92
# Epoch   800, train loss 0.866255, train error 29.50,  test loss 2.106985, test error 55.88
# Epoch   900, train loss 0.861879, train error 29.43,  test loss 2.175039, test error 55.50
# Training model with  30 hidden variables
# Epoch     0, train loss 2.099095, train error 77.68,  test loss 2.055555, test error 77.20
# Epoch   100, train loss 1.117802, train error 36.12,  test loss 1.335126, test error 49.33
# Epoch   200, train loss 0.956641, train error 31.62,  test loss 1.497430, test error 49.90
# Epoch   300, train loss 0.881151, train error 30.03,  test loss 1.676688, test error 51.65
# Epoch   400, train loss 0.817377, train error 27.57,  test loss 1.811845, test error 52.40
# Epoch   500, train loss 0.774561, train error 26.35,  test loss 1.958818, test error 52.50
# Epoch   600, train loss 0.716793, train error 24.32,  test loss 2.103014, test error 52.33
# Epoch   700, train loss 0.706469, train error 24.55,  test loss 2.308991, test error 53.83
# Epoch   800, train loss 0.677094, train error 23.53,  test loss 2.443941, test error 52.72
# Epoch   900, train loss 0.639639, train error 21.70,  test loss 2.656358, test error 54.35
# Training model with  35 hidden variables
# Epoch     0, train loss 2.197780, train error 81.45,  test loss 2.170802, test error 80.22
# Epoch   100, train loss 1.042906, train error 34.88,  test loss 1.371217, test error 49.30
# Epoch   200, train loss 0.779640, train error 26.25,  test loss 1.730219, test error 51.72
# Epoch   300, train loss 0.662354, train error 21.80,  test loss 2.130677, test error 53.05
# Epoch   400, train loss 0.570878, train error 18.90,  test loss 2.555213, test error 54.90
# Epoch   500, train loss 0.531354, train error 17.70,  test loss 2.955522, test error 55.22
# Epoch   600, train loss 0.513814, train error 17.03,  test loss 3.258421, test error 55.28
# Epoch   700, train loss 0.517788, train error 17.95,  test loss 3.602419, test error 57.05
# Epoch   800, train loss 0.466012, train error 16.43,  test loss 3.907817, test error 56.97
# Epoch   900, train loss 0.422978, train error 14.10,  test loss 4.223235, test error 56.33
# Training model with  40 hidden variables
# Epoch     0, train loss 2.049244, train error 76.85,  test loss 1.992821, test error 74.82
# Epoch   100, train loss 0.922042, train error 29.65,  test loss 1.441890, test error 50.00
# Epoch   200, train loss 0.645020, train error 21.03,  test loss 1.927802, test error 51.78
# Epoch   300, train loss 0.487439, train error 15.47,  test loss 2.540585, test error 53.67
# Epoch   400, train loss 0.398935, train error 13.25,  test loss 3.303968, test error 55.28
# Epoch   500, train loss 0.356534, train error 12.30,  test loss 4.069477, test error 56.35
# Epoch   600, train loss 0.294376, train error 10.38,  test loss 4.888956, test error 58.20
# Epoch   700, train loss 0.248666, train error 8.43,  test loss 5.702590, test error 57.90
# Epoch   800, train loss 0.264757, train error 8.62,  test loss 6.417017, test error 57.85
# Epoch   900, train loss 0.255670, train error 8.90,  test loss 7.068019, test error 58.53
# Training model with  45 hidden variables
# Epoch     0, train loss 2.089730, train error 77.35,  test loss 2.040817, test error 77.43
# Epoch   100, train loss 0.871787, train error 27.57,  test loss 1.559633, test error 52.20
# Epoch   200, train loss 0.526591, train error 16.50,  test loss 2.284428, test error 54.12
# Epoch   300, train loss 0.352098, train error 10.82,  test loss 3.228152, test error 55.55
# Epoch   400, train loss 0.244240, train error 7.47,  test loss 4.309851, test error 57.03
# Epoch   500, train loss 0.212144, train error 7.20,  test loss 5.466428, test error 56.88
# Epoch   600, train loss 0.233669, train error 8.12,  test loss 6.669658, test error 57.33
# Epoch   700, train loss 0.324054, train error 11.03,  test loss 7.938096, test error 57.35
# Epoch   800, train loss 0.014635, train error 0.03,  test loss 8.919566, test error 57.40
# Epoch   900, train loss 0.009407, train error 0.00,  test loss 9.687389, test error 57.58
# Training model with  50 hidden variables
# Epoch     0, train loss 2.076018, train error 77.75,  test loss 2.034144, test error 78.05
# Epoch   100, train loss 0.710185, train error 21.70,  test loss 1.563013, test error 50.65
# Epoch   200, train loss 0.362220, train error 10.90,  test loss 2.597950, test error 53.67
# Epoch   300, train loss 0.183763, train error 4.62,  test loss 4.042900, test error 55.20
# Epoch   400, train loss 0.056622, train error 0.72,  test loss 5.648695, test error 55.67
# Epoch   500, train loss 0.021682, train error 0.00,  test loss 6.720656, test error 56.17
# Epoch   600, train loss 0.007522, train error 0.00,  test loss 7.368821, test error 55.65
# Epoch   700, train loss 0.005225, train error 0.00,  test loss 7.819573, test error 55.97
# Epoch   800, train loss 0.004061, train error 0.00,  test loss 8.175490, test error 55.90
# Epoch   900, train loss 0.003290, train error 0.00,  test loss 8.462637, test error 56.03
# Training model with  55 hidden variables
# Epoch     0, train loss 2.035081, train error 76.93,  test loss 1.956503, test error 75.00
# Epoch   100, train loss 0.660273, train error 20.20,  test loss 1.696959, test error 52.90
# Epoch   200, train loss 0.238905, train error 6.03,  test loss 3.024809, test error 54.22
# Epoch   300, train loss 0.047683, train error 0.10,  test loss 4.849319, test error 55.90
# Epoch   400, train loss 0.015279, train error 0.00,  test loss 5.976999, test error 55.70
# Epoch   500, train loss 0.008759, train error 0.00,  test loss 6.642188, test error 55.72
# Epoch   600, train loss 0.005943, train error 0.00,  test loss 7.107764, test error 55.75
# Epoch   700, train loss 0.004443, train error 0.00,  test loss 7.479128, test error 55.95
# Epoch   800, train loss 0.003492, train error 0.00,  test loss 7.776138, test error 56.03
# Epoch   900, train loss 0.002852, train error 0.00,  test loss 8.023675, test error 55.80
# Training model with  60 hidden variables
# Epoch     0, train loss 2.095022, train error 77.10,  test loss 2.076334, test error 77.78
# Epoch   100, train loss 0.528631, train error 15.35,  test loss 1.773894, test error 50.50
# Epoch   200, train loss 0.123486, train error 1.57,  test loss 3.340868, test error 53.55
# Epoch   300, train loss 0.021627, train error 0.03,  test loss 4.725770, test error 54.17
# Epoch   400, train loss 0.009782, train error 0.00,  test loss 5.410896, test error 53.78
# Epoch   500, train loss 0.006066, train error 0.00,  test loss 5.861761, test error 53.55
# Epoch   600, train loss 0.004301, train error 0.00,  test loss 6.201933, test error 53.62
# Epoch   700, train loss 0.003299, train error 0.00,  test loss 6.466914, test error 53.80
# Epoch   800, train loss 0.002638, train error 0.00,  test loss 6.685281, test error 53.72
# Epoch   900, train loss 0.002188, train error 0.00,  test loss 6.872627, test error 53.70
# Training model with  70 hidden variables
# Epoch     0, train loss 2.037023, train error 75.55,  test loss 1.995936, test error 76.25
# Epoch   100, train loss 0.379748, train error 10.05,  test loss 1.972435, test error 51.35
# Epoch   200, train loss 0.035847, train error 0.00,  test loss 3.604545, test error 53.00
# Epoch   300, train loss 0.011553, train error 0.00,  test loss 4.442757, test error 53.30
# Epoch   400, train loss 0.006318, train error 0.00,  test loss 4.908636, test error 53.33
# Epoch   500, train loss 0.004231, train error 0.00,  test loss 5.233234, test error 53.40
# Epoch   600, train loss 0.003123, train error 0.00,  test loss 5.482964, test error 53.47
# Epoch   700, train loss 0.002441, train error 0.00,  test loss 5.682568, test error 53.38
# Epoch   800, train loss 0.001991, train error 0.00,  test loss 5.848363, test error 53.33
# Epoch   900, train loss 0.001672, train error 0.00,  test loss 5.990392, test error 53.38
# Training model with  80 hidden variables
# Epoch     0, train loss 2.034982, train error 75.78,  test loss 1.979716, test error 76.38
# Epoch   100, train loss 0.201984, train error 2.72,  test loss 2.064694, test error 50.42
# Epoch   200, train loss 0.018912, train error 0.00,  test loss 3.360873, test error 51.83
# Epoch   300, train loss 0.007823, train error 0.00,  test loss 3.891156, test error 52.00
# Epoch   400, train loss 0.004676, train error 0.00,  test loss 4.211906, test error 52.12
# Epoch   500, train loss 0.003233, train error 0.00,  test loss 4.442086, test error 52.25
# Epoch   600, train loss 0.002439, train error 0.00,  test loss 4.618382, test error 52.28
# Epoch   700, train loss 0.001937, train error 0.00,  test loss 4.763809, test error 52.38
# Epoch   800, train loss 0.001596, train error 0.00,  test loss 4.887891, test error 52.47
# Epoch   900, train loss 0.001351, train error 0.00,  test loss 4.991607, test error 52.50
# Training model with  90 hidden variables
# Epoch     0, train loss 1.989183, train error 73.90,  test loss 1.932009, test error 74.45
# Epoch   100, train loss 0.132024, train error 0.90,  test loss 2.173120, test error 50.80
# Epoch   200, train loss 0.014211, train error 0.00,  test loss 3.205325, test error 50.90
# Epoch   300, train loss 0.006329, train error 0.00,  test loss 3.633781, test error 51.15
# Epoch   400, train loss 0.003875, train error 0.00,  test loss 3.892526, test error 51.40
# Epoch   500, train loss 0.002736, train error 0.00,  test loss 4.080934, test error 51.45
# Epoch   600, train loss 0.002083, train error 0.00,  test loss 4.226634, test error 51.65
# Epoch   700, train loss 0.001669, train error 0.00,  test loss 4.347890, test error 51.65
# Epoch   800, train loss 0.001383, train error 0.00,  test loss 4.448741, test error 51.70
# Epoch   900, train loss 0.001175, train error 0.00,  test loss 4.538466, test error 51.70
# Training model with 100 hidden variables
# Epoch     0, train loss 2.009303, train error 74.18,  test loss 1.962748, test error 75.00
# Epoch   100, train loss 0.098027, train error 0.30,  test loss 2.166333, test error 50.78
# Epoch   200, train loss 0.012330, train error 0.00,  test loss 2.940619, test error 49.92
# Epoch   300, train loss 0.005765, train error 0.00,  test loss 3.281393, test error 50.00
# Epoch   400, train loss 0.003598, train error 0.00,  test loss 3.496253, test error 49.88
# Epoch   500, train loss 0.002561, train error 0.00,  test loss 3.653190, test error 49.92
# Epoch   600, train loss 0.001960, train error 0.00,  test loss 3.774802, test error 49.88
# Epoch   700, train loss 0.001572, train error 0.00,  test loss 3.874372, test error 49.83
# Epoch   800, train loss 0.001305, train error 0.00,  test loss 3.960693, test error 49.95
# Epoch   900, train loss 0.001110, train error 0.00,  test loss 4.034813, test error 49.88
# Training model with 120 hidden variables
# Epoch     0, train loss 1.937271, train error 71.78,  test loss 1.878141, test error 72.50
# Epoch   100, train loss 0.051786, train error 0.00,  test loss 2.209663, test error 49.97
# Epoch   200, train loss 0.009402, train error 0.00,  test loss 2.820756, test error 50.22
# Epoch   300, train loss 0.004665, train error 0.00,  test loss 3.099280, test error 50.42
# Epoch   400, train loss 0.002988, train error 0.00,  test loss 3.277820, test error 50.42
# Epoch   500, train loss 0.002151, train error 0.00,  test loss 3.407491, test error 50.28
# Epoch   600, train loss 0.001665, train error 0.00,  test loss 3.510010, test error 50.28
# Epoch   700, train loss 0.001347, train error 0.00,  test loss 3.596448, test error 50.33
# Epoch   800, train loss 0.001124, train error 0.00,  test loss 3.669996, test error 50.33
# Epoch   900, train loss 0.000961, train error 0.00,  test loss 3.733854, test error 50.47
# Training model with 140 hidden variables
# Epoch     0, train loss 1.951100, train error 71.85,  test loss 1.880994, test error 72.97
# Epoch   100, train loss 0.035362, train error 0.00,  test loss 2.099828, test error 48.70
# Epoch   200, train loss 0.008039, train error 0.00,  test loss 2.571787, test error 48.90
# Epoch   300, train loss 0.004132, train error 0.00,  test loss 2.798418, test error 48.90
# Epoch   400, train loss 0.002694, train error 0.00,  test loss 2.946837, test error 49.05
# Epoch   500, train loss 0.001960, train error 0.00,  test loss 3.056782, test error 49.15
# Epoch   600, train loss 0.001525, train error 0.00,  test loss 3.144165, test error 48.97
# Epoch   700, train loss 0.001239, train error 0.00,  test loss 3.216762, test error 48.78
# Epoch   800, train loss 0.001037, train error 0.00,  test loss 3.278862, test error 48.80
# Epoch   900, train loss 0.000889, train error 0.00,  test loss 3.333428, test error 48.78
# Training model with 160 hidden variables
# Epoch     0, train loss 1.946994, train error 72.45,  test loss 1.865768, test error 71.93
# Epoch   100, train loss 0.027879, train error 0.00,  test loss 2.087530, test error 48.62
# Epoch   200, train loss 0.007114, train error 0.00,  test loss 2.491822, test error 48.97
# Epoch   300, train loss 0.003725, train error 0.00,  test loss 2.688589, test error 48.95
# Epoch   400, train loss 0.002453, train error 0.00,  test loss 2.821665, test error 48.90
# Epoch   500, train loss 0.001795, train error 0.00,  test loss 2.919772, test error 48.88
# Epoch   600, train loss 0.001402, train error 0.00,  test loss 2.999910, test error 49.05
# Epoch   700, train loss 0.001141, train error 0.00,  test loss 3.066178, test error 49.10
# Epoch   800, train loss 0.000958, train error 0.00,  test loss 3.122652, test error 48.92
# Epoch   900, train loss 0.000822, train error 0.00,  test loss 3.172172, test error 48.90
# Training model with 180 hidden variables
# Epoch     0, train loss 1.929920, train error 70.93,  test loss 1.870181, test error 73.00
# Epoch   100, train loss 0.025052, train error 0.00,  test loss 2.062721, test error 48.00
# Epoch   200, train loss 0.006662, train error 0.00,  test loss 2.436469, test error 47.85
# Epoch   300, train loss 0.003555, train error 0.00,  test loss 2.622337, test error 47.95
# Epoch   400, train loss 0.002353, train error 0.00,  test loss 2.747598, test error 48.00
# Epoch   500, train loss 0.001729, train error 0.00,  test loss 2.840650, test error 47.85
# Epoch   600, train loss 0.001353, train error 0.00,  test loss 2.916709, test error 48.00
# Epoch   700, train loss 0.001104, train error 0.00,  test loss 2.978961, test error 48.00
# Epoch   800, train loss 0.000928, train error 0.00,  test loss 3.032416, test error 47.90
# Epoch   900, train loss 0.000797, train error 0.00,  test loss 3.079669, test error 47.90
# Training model with 200 hidden variables
# Epoch     0, train loss 1.914445, train error 69.43,  test loss 1.837064, test error 70.88
# Epoch   100, train loss 0.020759, train error 0.00,  test loss 1.977502, test error 47.92
# Epoch   200, train loss 0.006034, train error 0.00,  test loss 2.292259, test error 48.15
# Epoch   300, train loss 0.003288, train error 0.00,  test loss 2.453627, test error 48.30
# Epoch   400, train loss 0.002198, train error 0.00,  test loss 2.562952, test error 48.28
# Epoch   500, train loss 0.001624, train error 0.00,  test loss 2.644723, test error 48.38
# Epoch   600, train loss 0.001277, train error 0.00,  test loss 2.710569, test error 48.35
# Epoch   700, train loss 0.001045, train error 0.00,  test loss 2.766316, test error 48.35
# Epoch   800, train loss 0.000880, train error 0.00,  test loss 2.813692, test error 48.33
# Epoch   900, train loss 0.000758, train error 0.00,  test loss 2.855567, test error 48.38
# Training model with 250 hidden variables
# Epoch     0, train loss 1.910745, train error 69.97,  test loss 1.831929, test error 72.43
# Epoch   100, train loss 0.016860, train error 0.00,  test loss 1.951969, test error 48.40
# Epoch   200, train loss 0.005333, train error 0.00,  test loss 2.200692, test error 48.15
# Epoch   300, train loss 0.002966, train error 0.00,  test loss 2.339690, test error 48.03
# Epoch   400, train loss 0.002002, train error 0.00,  test loss 2.431613, test error 48.03
# Epoch   500, train loss 0.001491, train error 0.00,  test loss 2.502441, test error 48.03
# Epoch   600, train loss 0.001177, train error 0.00,  test loss 2.559266, test error 47.95
# Epoch   700, train loss 0.000966, train error 0.00,  test loss 2.606884, test error 48.00
# Epoch   800, train loss 0.000816, train error 0.00,  test loss 2.647811, test error 47.85
# Epoch   900, train loss 0.000704, train error 0.00,  test loss 2.683636, test error 47.88
# Training model with 300 hidden variables
# Epoch     0, train loss 1.895446, train error 69.70,  test loss 1.805978, test error 70.25
# Epoch   100, train loss 0.014684, train error 0.00,  test loss 1.877837, test error 47.22
# Epoch   200, train loss 0.004869, train error 0.00,  test loss 2.102592, test error 46.80
# Epoch   300, train loss 0.002750, train error 0.00,  test loss 2.225883, test error 46.92
# Epoch   400, train loss 0.001870, train error 0.00,  test loss 2.308867, test error 47.10
# Epoch   500, train loss 0.001398, train error 0.00,  test loss 2.372390, test error 47.12
# Epoch   600, train loss 0.001107, train error 0.00,  test loss 2.423843, test error 47.25
# Epoch   700, train loss 0.000911, train error 0.00,  test loss 2.467329, test error 47.17
# Epoch   800, train loss 0.000771, train error 0.00,  test loss 2.504532, test error 47.25
# Epoch   900, train loss 0.000666, train error 0.00,  test loss 2.537282, test error 47.12
# Training model with 400 hidden variables
# Epoch     0, train loss 1.822924, train error 65.38,  test loss 1.773183, test error 68.28
# Epoch   100, train loss 0.011589, train error 0.00,  test loss 1.738592, test error 44.72
# Epoch   200, train loss 0.004149, train error 0.00,  test loss 1.911635, test error 44.58
# Epoch   300, train loss 0.002407, train error 0.00,  test loss 2.009049, test error 44.42
# Epoch   400, train loss 0.001659, train error 0.00,  test loss 2.077671, test error 44.25
# Epoch   500, train loss 0.001251, train error 0.00,  test loss 2.129926, test error 44.35
# Epoch   600, train loss 0.000996, train error 0.00,  test loss 2.172591, test error 44.15
# Epoch   700, train loss 0.000823, train error 0.00,  test loss 2.208217, test error 44.20
# Epoch   800, train loss 0.000699, train error 0.00,  test loss 2.239023, test error 44.17
# Epoch   900, train loss 0.000605, train error 0.00,  test loss 2.266160, test error 44.22

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
